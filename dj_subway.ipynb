# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 대전 지하철 2020년 1월 ~ 6월 시간대별 승하차 데이터

# %%
import csv
f = open('dj_subway.csv')
data = csv.reader(f)
next(data)
for row in data :
    print(row)
    
f.close()

# %%
dj = pd.read_csv('dj_subway.csv', encoding='cp949').set_index('날짜')

# %%
dj.head()
# Out:
#              역번호  역명  구분  03~04시  04~05시  05~06시  06~07시  07~08시  08~09시  \
# 날짜
# 2020-01-01  1101  판암  승차       0       0      40      41      68     127
# 2020-01-01  1101  판암  하차       0       0      16      72      49      63
# 2020-01-01  1102  신흥  승차       0       1      30      26      20      56
# 2020-01-01  1102  신흥  하차       0       0       5      20      27      27
# 2020-01-01  1103  대동  승차       0       0      39      40      50     107
#
#             09~10시  ...  17~18시  18~19시  19~20시  20~21시  21~22시  22~23시  \
# 날짜                  ...
# 2020-01-01     163  ...     148     122      93      79      41      35
# 2020-01-01      78  ...     218     143     148     120     132     118
# 2020-01-01      92  ...      82      67      32      31      17      12
# 2020-01-01      26  ...      95      77      73      46      52      38
# 2020-01-01     131  ...     163     164     109      91      73      56
#
#             23~00시  00~01시  01~02시  02~03시
# 날짜
# ...

# %%
geton = dj[dj['구분'] == '승차']
getoff= dj[dj['구분'] == '하차']

# %%
geton
# Out:
#              역번호      역명  구분  03~04시  04~05시  05~06시  06~07시  07~08시  08~09시  \
# 날짜
# 2020-01-01  1101      판암  승차       0       0      40      41      68     127
# 2020-01-01  1102      신흥  승차       0       1      30      26      20      56
# 2020-01-01  1103      대동  승차       0       0      39      40      50     107
# 2020-01-01  1104      대전  승차       0       0      16      73      76     153
# 2020-01-01  1105     중앙로  승차       0       0      34      35      26      47
# ...          ...     ...  ..     ...     ...     ...     ...     ...     ...
# 2020-06-30  1118     현충원  승차       0       0       7      28     116     172
# 2020-06-30  1119  월드컵경기장  승차       0       0      12      61     212     351
# 2020-06-30  1120      노은  승차       0       0      18      67     240     305
# 2020-06-30  1121      지족  승차       0       0      16      36     153     162
# 2020-06-30  1122      반석  승차       0       0      43     181     617     825
#
# ...

# %%
dj.groupby(['역명','구분']).sum()
# Out:
#               역번호  03~04시  04~05시  05~06시  06~07시  07~08시  08~09시  09~10시  \
# 역명     구분
# 갈마     승차  202566       0       4    8647   13636   31185   55463   30202
#        하차  202566       0       0    2113    4427   10092   17518   12837
# 갑천     승차  202930       0      33    1811    4799   10013   21402   10616
#        하차  202930       0      32    1138    2847    4147   10480    5864
# 구암     승차  203294       0       1    6432    9712   22572   40337   21580
#        하차  203294       0       0    1733    6548   13693   22281   17243
# 노은     승차  203840       0       6    4312   10578   32076   48304   26130
#        하차  203840       0       0    2214    5695   17920   35262   32151
# 대동     승차  200746       0      21   10593   19390   48659   79566   42680
#        하차  200746       0       1    2911    6134   16197   31863   18384
# 대전     승차  200928       0      58    5021   17686   52222   78174   65755
# ...

# %%
dj.groupby(['역명'])['06~07시','07~08시','08~09시'].sum().plot()
# Out:
# <ipython-input-39-5b11d4eaf96c>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   dj.groupby(['역명'])['06~07시','07~08시','08~09시'].sum().plot()
# <AxesSubplot:xlabel='역명'>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import platform
platform.system()
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False) #마이너스폰트 설정
import seaborn as sns

# %%
#plt.figure(dpi = 200)
bar = geton.plot.bar(grid=True)
bar.set_xlabel("역명")
bar.set_ylabel("인원")
#plt.plot(color='skyblue')
plt.show()

# %%
https://zzsza.github.io/mlops/2020/03/08/airflow-with-notebook-using-papermill/
